# %%
# !pip install git+https://github.com/johnwmillr/LyricsGenius.git
# Out:
# Collecting git+https://github.com/johnwmillr/LyricsGenius.git
#   Cloning https://github.com/johnwmillr/LyricsGenius.git to c:\users\camer\appdata\local\temp\pip-req-build-hgo7zs98
#   Resolved https://github.com/johnwmillr/LyricsGenius.git to commit 2b6a4f8bbcfbad942440e505f7f244f491af8eb6
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: beautifulsoup4>=4.12.3 in c:\users\camer\anaconda3\lib\site-packages (from lyricsgenius==3.7.5) (4.12.3)
# Requirement already satisfied: requests>=2.27.1 in c:\users\camer\anaconda3\lib\site-packages (from lyricsgenius==3.7.5) (2.32.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\camer\anaconda3\lib\site-packages (from beautifulsoup4>=4.12.3->lyricsgenius==3.7.5) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\camer\anaconda3\lib\site-packages (from requests>=2.27.1->lyricsgenius==3.7.5) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\camer\anaconda3\lib\site-packages (from requests>=2.27.1->lyricsgenius==3.7.5) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\camer\anaconda3\lib\site-packages (from requests>=2.27.1->lyricsgenius==3.7.5) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\camer\anaconda3\lib\site-packages (from requests>=2.27.1->lyricsgenius==3.7.5) (2025.11.12)
#   Running command git clone --filter=blob:none --quiet https://github.com/johnwmillr/LyricsGenius.git 'C:\Users\camer\AppData\Local\Temp\pip-req-build-hgo7zs98'

# %%
client_access_token = "w_aWx0rdBwUR_qT_3Pbmm_TCe65XKDjsZ-ebGbC-oCw2qFjUYesiQl6dbKGRc0R5"

# %%
import lyricsgenius
LyricsGenius = lyricsgenius.Genius(client_access_token)

# %%
songs = ["Come Here", "Double Negative (Skeleton Milkshake)", "Cancel Me", "10x Stronger", "Good Game", "Why", "Chicken Tenders", "Whats For Dinner?", "Vampire", "Superstar Sh*t", "Politics & Violence", "Joe Blazey", "Wurli", "Florida"]
directory = r"C:/Users/camer/OneDrive/Documents/University/MA Digital Humanities/Collecting Data/Assignment_2/Assignment_2/data"

for song in songs:
    specific_song = LyricsGenius.search_song("Dominic Fike", song)
    specific_song.save_lyrics(extension='txt')
# Out:
# Searching for "Dominic Fike" by Come Here...
# Done.
# Wrote saved_song_lyrics_dominic_fike_come_here.txt.
# Searching for "Dominic Fike" by Double Negative (Skeleton Milkshake)...
# Done.
# Wrote saved_song_lyrics_dominic_fike_double_negative_(skeleton_milkshake).txt.
# Searching for "Dominic Fike" by Cancel Me...
# Done.
# Wrote saved_song_lyrics_dominic_fike_cancel_me.txt.
# Searching for "Dominic Fike" by 10x Stronger...
# Done.
# Wrote saved_song_lyrics_dominic_fike_10x_stronger.txt.
# Searching for "Dominic Fike" by Good Game...
# Done.
# Wrote saved_song_lyrics_dominic_fike_good_game.txt.
# Searching for "Dominic Fike" by Why...
# Done.
# Wrote saved_song_lyrics_dominic_fike_why.txt.
# Searching for "Dominic Fike" by Chicken Tenders...
# Done.
# Wrote saved_song_lyrics_dominic_fike_chicken_tenders.txt.
# Searching for "Dominic Fike" by Whats For Dinner?...
# Done.
# Wrote saved_song_lyrics_dominic_fike_whats_for_dinner.txt.
# Searching for "Dominic Fike" by Vampire...
# Done.
# Wrote saved_song_lyrics_dominic_fike_vampire.txt.
# Searching for "Dominic Fike" by Superstar Sh*t...
# Done.
# Wrote saved_song_lyrics_dominic_fike_superstar_sht.txt.
# Searching for "Dominic Fike" by Politics & Violence...
# Done.
# Wrote saved_song_lyrics_dominic_fike_politics_&_violence.txt.
# Searching for "Dominic Fike" by Joe Blazey...
# Done.
# Wrote saved_song_lyrics_dominic_fike_joe_blazey.txt.
# Searching for "Dominic Fike" by Wurli...
# Done.
# Wrote saved_song_lyrics_dominic_fike_wurli.txt.
# Searching for "Dominic Fike" by Florida...
# Done.
# Wrote saved_song_lyrics_dominic_fike_florida.txt.
