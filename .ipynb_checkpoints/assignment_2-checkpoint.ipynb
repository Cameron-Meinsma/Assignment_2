# %%
import azapi

API = azapi.AZlyrics('google', accuracy=0.5)

API.artist = 'Dominic'
API.title = 'Fike'

API.getLyrics(save=True, ext='lrc')

print(API.lyrics)

# Correct Artist and Title are updated from webpage
print(API.title, API.artist)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import azapi
#       3 API = azapi.AZlyrics('google', accuracy=0.5)
#       5 API.artist = 'Dominic'
#
# ModuleNotFoundError: No module named 'azapi'
